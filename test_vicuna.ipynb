# %%
from langchain_ollama import OllamaLLM
from typing_extensions import TypedDict
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langgraph.graph import StateGraph, START, END
from db_create import CargaDeArchivos
import re

# %%
a= CargaDeArchivos()
a.run_carga()
db_conn= a.conn


class State(TypedDict):
    """
    Represents the state of the workflow, including the question, schema, database connection,
    relevance, SQL query, query result, and other metadata.
    """
    question: str
    schema: str
    db_conn: None
    relevance: str
    sql_query: str
    query_result: str
    sql_error: bool
    final_answer: str
    attempts: int

# %%
def convert_nl_to_sql(state: State):
    """
    Converts a natural language question into an SQL query based on the database schema.

    Args:
        state (State): The current state of the workflow.
        config (RunnableConfig): Configuration for the runnable.

    Returns:
        State: Updated state with the generated SQL query.
    """
    question = state["question"]
    print(f"Converting question to SQL {question}")
    system = """
    You are an SQL assistant specialized in DuckDB. Your task is to generate accurate SQL queries based on natural language questions, following the provided schema.

    ### Database Schema  
    #### Table: "cases"
    - "id" (VARCHAR): Primary key.
    - "insurance" (BIGINT): Foreign key to insurance.
    - "avg_time" (DOUBLE): Duration (seconds) from case initiation to closure.
    - "type" (VARCHAR): Insurance category.
    - "branch" (VARCHAR): Policy branch.
    - "ramo" (VARCHAR): Coverage type.
    - "broker" (VARCHAR): Broker for the policy.
    - "state" (VARCHAR): Current case state.
    - "client" (VARCHAR): Client who bought the insurance.
    - "creator" (VARCHAR): Employee managing the case.
    - "value" (BIGINT): Insurance monetary value.
    - "approved" (BOOLEAN): TRUE if approved, else FALSE.
    - "insurance_creation" (TIMESTAMP_NS): Policy creation timestamp.
    - "insurance_start" (TIMESTAMP_NS): Coverage start timestamp.
    - "insurance_end" (TIMESTAMP_NS): Coverage end timestamp.

    #### Table: "activity"
    - "id" (BIGINT): Primary key.
    - "case" (VARCHAR): Foreign key to "cases"."id".
    - "timestamp" (TIMESTAMP_NS): Activity timestamp.
    - "name" (VARCHAR): Name of the activity.
    - "case_index" (BIGINT): Alias for "id".
    - "tpt" (DOUBLE): Activity duration (seconds).

    ### Query Guidelines  
    1. **Use Table Aliases**: "cases" → c, "activity" → a.
    2. **Always Reference Columns with Aliases**: c."id", a."case".
    3. **Handle Aggregations**: Include non-aggregated columns in GROUP BY.
    4. **Date & Time Calculations**: Use EXTRACT(DAY FROM ...) for durations.
    5. **Filtering Conditions**: Use TRUE/FALSE for boolean values.
    6. **Use Explicit Joins**: Avoid implicit joins.
    7. **Optimize for Performance**: Use indexes, avoid unnecessary calculations, and limit results when needed.
    8. **Restrict Queries to Existing Tables**: Only use "cases" and "activity" tables.

    ### Output Format  
    - Return only the SQL query, with no extra formatting.  
    - Do **NOT** include language tags like `sql`, `vbnet`, or any other markers.  
    """



    llm= OllamaLLM(model="vicuna:latest",temperature="0.0")
    
    convert_prompt = ChatPromptTemplate.from_messages(
        [
            ("system", system),
            ("human", "Question: {question}"),
        ]
    )
    sql_generator = convert_prompt | llm
    result = sql_generator.invoke({"question": question})
    message= re.sub(r'^\s*```sql\s*|\s*```$', '', result.strip(), flags=re.IGNORECASE)
    state["sql_query"] = message
    print(f"Generated SQL query: {state['sql_query']}")
    return state


def execute_sql(state:State):
    """
    Executes the SQL query on the  database and retrieves the results.

    Args:
        state (State): The current state of the workflow.
        config (RunnableConfig): Configuration for the runnable.

    Returns:
        State: Updated state with the query results or error information.
    """
    sql_query = state["sql_query"].strip()
    db_conn = state["db_conn"]  
    print(f"Executing SQL query: {sql_query}")

    try:
        # Ensure the query targets only the allowed tables
        allowed_tables = ["cases", "activity"]
        if not any(table in sql_query.lower() for table in allowed_tables):
            raise ValueError(f"Query must target only the tables: {', '.join(allowed_tables)}.")

        # Execute the SQL query using the connection
        cursor = db_conn.cursor()
        cursor.execute(sql_query)

        # Fetch results if it's a SELECT query
        if sql_query.lower().startswith("select"):
            rows = cursor.fetchall()
            columns = [desc[0] for desc in cursor.description]

            # Format the output
            if rows:
                formatted_result = "\n".join(
                    ", ".join(f"{col}: {row[idx]}" for idx, col in enumerate(columns))
                    for row in rows
                )
                print("SQL SELECT query executed successfully.")
            else:
                formatted_result = "No results found."
                print("SQL SELECT query executed successfully but returned no rows.")

            state["query_rows"] = rows
        else:
            formatted_result = "The action has been successfully completed."
            print("SQL command executed successfully.")

        state["query_result"] = formatted_result
        state["sql_error"] = False

    except Exception as e:
        state["query_result"] = f"Error executing SQL query: {str(e)}"
        state["sql_error"] = True
        print(f"Error executing SQL query: {str(e)}")
    print(state['query_result'])
    return state

# %%
test_cases = [
    {"question": "How many cases are there in total in the database?",
    "expected_sql": 'SELECT COUNT(*) FROM cases;'},
    {"question": "How many activities have been recorded?",
    "expected_sql": 'SELECT COUNT(*) FROM activity;'},
    {"question": "What are the different types of insurance available?",
    "expected_sql": 'SELECT DISTINCT type FROM cases;'},
    {"question": "What is the total value of approved insurance policies?",
    "expected_sql": 'SELECT SUM(value) FROM cases WHERE approved = 1;'},
    {"question": "How many cases were created in January?",
    "expected_sql": 'SELECT COUNT(*) FROM cases WHERE EXTRACT(MONTH FROM insurance_creation) = 1;'},
    {"question": "Who is the broker with the most assigned cases?",
    "expected_sql": 'SELECT brocker FROM cases GROUP BY brocker ORDER BY COUNT(*) DESC LIMIT 1;'},
    {"question": "What is the most frequent activity in the database?",
    "expected_sql": 'SELECT name FROM activity GROUP BY name ORDER BY COUNT(*) DESC LIMIT 1;'},
    {"question": "What is the total insurance value for each type of 'ramo'?",
    "expected_sql": 'SELECT ramo, SUM(value) FROM cases GROUP BY ramo;'},
    {"question": "On average, how long does it take for an insurance policy to be approved?",
    "expected_sql": 'SELECT AVG(EXTRACT(DAY FROM insurance_start - insurance_creation)) FROM cases WHERE approved = 1;'},
    {"question": "What is the average number of activities per case?",
    "expected_sql": 'SELECT COUNT(activity.id) / COUNT(DISTINCT cases.id) FROM activity INNER JOIN cases ON activity.case = cases.id;'},
    {"question": "What is the most frequent activity performed in approved cases?",
    "expected_sql": 'SELECT activity.name FROM activity INNER JOIN cases ON activity.case = cases.id WHERE cases.approved = TRUE GROUP BY activity.name ORDER BY COUNT(activity.id) DESC LIMIT 1;'},
    {"question": "What is the total duration of all activities for each case?",
    "expected_sql": 'SELECT activity.case, SUM(activity.tpt) FROM activity GROUP BY activity.case;'},
    {"question": "What is the total value of cases that have at least one recorded activity?",
    "expected_sql": 'SELECT SUM(cases.value) FROM cases WHERE cases.id IN (SELECT DISTINCT case FROM activity);'},
    
]

# %%
import time
import pandas as pd

def time_query_generation(state):
    """
    Measures the execution time of the model generating an SQL query.

    Args:
        state (dict): The state object that stores the query and result.

    Returns:
        dict: Updated state containing the query, execution time, and SQL output.
    """
    start_time = time.time()
    try:
        convert_nl_to_sql(state)  # Generates SQL query
        execute_sql(state)  # Executes SQL query
    except Exception as e:
        state["sql_query"] = f"Error: {e}"

    execution_time = time.time() - start_time
    state["execution_time"] = execution_time
    return state

# %%
results = []

# Run tests
for test in test_cases:
    state = {"question": test["question"], "expected_sql": test["expected_sql"],"db_conn":db_conn}
    result_state = time_query_generation(state)
    
    results.append({
        "Question": test["question"],
        "Expected SQL Query": test["expected_sql"],
        "Generated SQL Query": result_state['sql_query'],
        "Query Result": result_state["query_result"],
        "Execution Time (s)": result_state["execution_time"]
    })

# Convert results to DataFrame
df_results = pd.DataFrame(results)
# Out:
# Converting question to SQL How many cases are there in total in the database?
# Generated SQL query: SELECT COUNT(*) FROM cases;
# Executing SQL query: SELECT COUNT(*) FROM cases;
# SQL SELECT query executed successfully.
# count_star(): 1000
# Converting question to SQL How many activities have been recorded?
# Generated SQL query: SELECT COUNT(a."id") AS "number_of_activities"
# FROM activity a
# JOIN cases c ON a."case" = c."id"
# GROUP BY a."case", a."timestamp", a."name"
# Executing SQL query: SELECT COUNT(a."id") AS "number_of_activities"
# FROM activity a
# JOIN cases c ON a."case" = c."id"
# GROUP BY a."case", a."timestamp", a."name"
# SQL SELECT query executed successfully.
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# number_of_activities: 1
# ...
# id: 5287, total_duration: 703918.8579409999
# id: 695, total_duration: 1129985.5564330001
# id: 4886, total_duration: 928954.4003460001
# id: 3367, total_duration: 869114.7729829999
# id: 2179, total_duration: 1198259.5708219998
# id: 5203, total_duration: 1032721.811212
# id: 2326, total_duration: 229681.633501
# id: 6095, total_duration: 837306.4079670002
# id: 2961, total_duration: 242650.1155
# id: 485, total_duration: 417867.742745
# id: 3668, total_duration: 1186119.4542759995
# id: 629, total_duration: 988061.57026
# id: 5173, total_duration: 139721.817265
# id: 3622, total_duration: 955937.0223239997
# id: 230, total_duration: 854113.916933
# id: 2291, total_duration: 381616.542408
# id: 8135, total_duration: 332820.72865899996
# id: 5040, total_duration: 443756.20839700004
# id: 1929, total_duration: 193710.631639
# id: 1669, total_duration: 853437.8939830001
# id: 8320, total_duration: 1825007.2882020003
# id: 9473, total_duration: 687378.300283
# id: 6600, total_duration: 457695.84395199997
# id: 2247, total_duration: 182808.192636
# id: 670, total_duration: 242914.45539800002
# id: 3786, total_duration: 117183.83458699999
# id: 5014, total_duration: 551424.782652
# id: 8686, total_duration: 1389300.5084399995
# id: 6911, total_duration: 862765.810523
# id: 7021, total_duration: 2350410.7550770007
# id: 7055, total_duration: 1469729.9813350001
# id: 9827, total_duration: 1165104.254582
# id: 3806, total_duration: 569101.949188
# id: 4575, total_duration: 983232.8694310001
# id: 7392, total_duration: 263180.14676499995
# id: 4802, total_duration: 931055.766808
# id: 8067, total_duration: 1743846.3207939996
# id: 2084, total_duration: 1260655.705218
# id: 7892, total_duration: 730773.944314
# id: 7100, total_duration: 1101437.068847
# id: 4472, total_duration: 937797.1381069999
# id: 9775, total_duration: 1930000.0121509999
# id: 544, total_duration: 850155.5792139999
# id: 8172, total_duration: 767764.864906
# id: 3913, total_duration: 541398.8013880001
# id: 1727, total_duration: 393042.912069
# id: 6612, total_duration: 351948.65512400004
# id: 5535, total_duration: 1826724.4728579996
# id: 81, total_duration: 333488.30893299996
# id: 6866, total_duration: 1335883.6268859997
# id: 2145, total_duration: 230414.32552100002
# id: 6638, total_duration: 1417923.5730920003
# id: 8998, total_duration: 1330822.4258109997
# id: 3148, total_duration: 684834.098201
# id: 5865, total_duration: 1508458.3126710001
# id: 6201, total_duration: 1036911.766668
# id: 3839, total_duration: 1955931.860014
# id: 105, total_duration: 1553033.361461
# id: 4824, total_duration: 588240.4677220001
# id: 8158, total_duration: 652187.430781
# id: 9236, total_duration: 610858.918283
# id: 8418, total_duration: 142741.19558399997
# id: 9272, total_duration: 219323.27330499998
# id: 4877, total_duration: 1173203.6595800002
# id: 602, total_duration: 1465700.712466
# id: 9829, total_duration: 1534271.55541
# id: 6512, total_duration: 421949.12678500003
# id: 2165, total_duration: 675239.1235860001
# id: 4516, total_duration: 1347115.722192
# id: 4903, total_duration: 979254.5938979998
# id: 9831, total_duration: 1017821.181897
# id: 6110, total_duration: 827450.266548
# id: 9914, total_duration: 140803.472366
# id: 7595, total_duration: 1678908.9158149997
# id: 5730, total_duration: 286480.03879
# id: 1373, total_duration: 870717.4282189999
# id: 9863, total_duration: 993208.2237419997
# id: 4923, total_duration: 1190716.273171
# id: 8679, total_duration: 2741893.7756739995
# id: 3194, total_duration: 839200.255901
# id: 2508, total_duration: 1116704.554515
# id: 169, total_duration: 545987.1201460001
# id: 4908, total_duration: 969349.7477890002
# id: 5142, total_duration: 870799.7392070001
# id: 6698, total_duration: 1711266.1813709994
# id: 2806, total_duration: 820088.476789
# id: 9120, total_duration: 1342144.4832769998
# id: 8585, total_duration: 698788.411408
# id: 2510, total_duration: 1860489.1162639996
# id: 8591, total_duration: 825038.2836290002
# id: 5970, total_duration: 356318.72838399996
# id: 6490, total_duration: 171407.74827500002
# id: 8184, total_duration: 1761737.2702729995
# id: 9446, total_duration: 538300.174143
# id: 445, total_duration: 1749073.819747
# id: 5054, total_duration: 994184.7698609999
# id: 1901, total_duration: 663959.949581
# id: 9667, total_duration: 1003944.2992179998
# id: 2837, total_duration: 2215339.686125
# id: 740, total_duration: 1304109.081051
# id: 8662, total_duration: 1698606.1978979998
# id: 8514, total_duration: 881655.8360319999
# id: 8403, total_duration: 836129.870792
# id: 501, total_duration: 1558017.7392799996
# id: 6905, total_duration: 252597.059922
# id: 8304, total_duration: 147352.067805
# id: 5279, total_duration: 864568.159471
# id: 4585, total_duration: 986642.282503
# id: 6096, total_duration: 1799904.409717
# id: 2010, total_duration: 238966.066823
# id: 216, total_duration: 2231356.2788290004
# id: 5659, total_duration: 248977.55020400003
# id: 5888, total_duration: 275638.309815
# id: 7726, total_duration: 1524234.4261430001
# id: 3765, total_duration: 236141.330054
# id: 9557, total_duration: 959231.959465
# id: 6193, total_duration: 878107.1318450001
# id: 5219, total_duration: 1179666.903908
# id: 4437, total_duration: 1374774.8956139998
# id: 4750, total_duration: 968259.7857240001
# id: 3426, total_duration: 1577002.2847269997
# id: 6098, total_duration: 992171.0221380002
# id: 5892, total_duration: 1951124.6305629998
# id: 3255, total_duration: 276370.132202
# id: 9752, total_duration: 753498.949899
# id: 6075, total_duration: 626679.94246
# id: 4547, total_duration: 1366628.580997
# id: 9977, total_duration: 1533623.5679809996
# id: 208, total_duration: 167622.262573
# id: 5193, total_duration: 1267007.167507
# id: 3404, total_duration: 2237975.225922
# id: 8801, total_duration: 1786398.8111519997
# id: 5541, total_duration: 285292.597053
# id: 261, total_duration: 919243.384326
# id: 9287, total_duration: 832656.516155
# id: 1980, total_duration: 1950745.995995
# id: 3788, total_duration: 846600.195352
# id: 3466, total_duration: 724185.54685
# id: 305, total_duration: 713166.2588749998
# id: 757, total_duration: 1025693.7092399999
# id: 1764, total_duration: 2341180.7962389993
# id: 4328, total_duration: 1786477.6993699998
# id: 7192, total_duration: 1147801.614089
# id: 9090, total_duration: 262242.96825499996
# id: 2066, total_duration: 3016088.422405998
# id: 5880, total_duration: 627508.796421
# id: 5240, total_duration: 384375.2146470001
# id: 4788, total_duration: 1858417.0063220004
# id: 4402, total_duration: 880319.1430849999
# id: 9713, total_duration: 2546302.6265509995
# id: 1973, total_duration: 2024095.243178999
# id: 3843, total_duration: 144316.09316999998
# id: 9200, total_duration: 882200.151625
# id: 4274, total_duration: 1167502.650899
# id: 4369, total_duration: 2282516.887577
# id: 89, total_duration: 1769991.891075
# id: 5290, total_duration: 344340.362484
# id: 5145, total_duration: 948455.351659
# id: 8186, total_duration: 1773467.5187889999
# id: 4461, total_duration: 1212386.3221759999
# id: 7148, total_duration: 323011.911594
# id: 2300, total_duration: 749127.7429270002
# id: 3301, total_duration: 834502.580374
# id: 6782, total_duration: 400542.579013
# id: 6826, total_duration: 1385560.7588429998
# id: 9488, total_duration: 100616.052543
# id: 7711, total_duration: 1684147.6844350006
# id: 2631, total_duration: 256681.975508
# id: 8524, total_duration: 1812713.8977599996
# id: 8665, total_duration: 142294.22158700004
# id: 984, total_duration: 381557.54310300003
# id: 9539, total_duration: 832929.9435600002
# id: 6387, total_duration: 952918.74319
# id: 1353, total_duration: 793249.4869049999
# id: 9992, total_duration: 208772.225075
# id: 6211, total_duration: 579628.0126090001
# id: 3341, total_duration: 347582.06245699996
# id: 3562, total_duration: 658819.244109
# id: 3897, total_duration: 211403.241154
# id: 950, total_duration: 1210497.9861350001
# id: 2040, total_duration: 242071.25953900002
# id: 5836, total_duration: 769048.3373950002
# id: 1812, total_duration: 1861171.9270500003
# id: 6049, total_duration: 430600.757364
# id: 5036, total_duration: 1343939.186592
# id: 1313, total_duration: 113156.475748
# id: 9757, total_duration: 917633.1974259999
# id: 9941, total_duration: 237022.75388700003
# id: 9398, total_duration: 148870.062019
# id: 8928, total_duration: 1564466.7749589998
# id: 4313, total_duration: 807288.2246799999
# id: 5437, total_duration: 936335.94464
# id: 3373, total_duration: 538390.464178
# id: 7883, total_duration: 1299905.827981
# id: 1595, total_duration: 1098752.9690379999
# id: 4805, total_duration: 1100868.7193250002
# id: 4933, total_duration: 1672098.2297170002
# id: 586, total_duration: 1021810.2964959999
# id: 7347, total_duration: 194858.768107
# id: 5097, total_duration: 1022482.0563870001
# id: 1859, total_duration: 215308.313161
# id: 1451, total_duration: 762269.895308
# id: 4011, total_duration: 919284.9915290002
# id: 9209, total_duration: 1174592.931817
# id: 5747, total_duration: 897704.801335
# id: 2192, total_duration: 833504.9089139999
# id: 4107, total_duration: 806797.4603570001
# id: 1391, total_duration: 1333438.734831
# id: 5244, total_duration: 842679.0753229999
# id: 697, total_duration: 1065678.894252
# id: 8118, total_duration: 814362.8341330001
# id: 5797, total_duration: 1118870.319216
# id: 2842, total_duration: 173710.911034
# id: 2144, total_duration: 1259660.949669
# id: 1732, total_duration: 1682303.728007
# id: 3750, total_duration: 1171329.0915920003
# id: 8180, total_duration: 1049532.3697699998
# id: 6739, total_duration: 447855.88821500004
# id: 8830, total_duration: 139923.39428900002
# id: 9354, total_duration: 238770.97811700002
# id: 8917, total_duration: 1194585.7638
# id: 9830, total_duration: 327800.880695
# id: 3893, total_duration: 1195308.7572469998
# id: 2640, total_duration: 3137680.7971610003
# id: 5632, total_duration: 373978.519798
# id: 1448, total_duration: 1257763.7387590003
# id: 637, total_duration: 223791.28032700001
# id: 8949, total_duration: 1762035.8034219996
# id: 811, total_duration: 282395.143034
# id: 5076, total_duration: 286203.32871699997
# id: 7402, total_duration: 560032.1252209999
# id: 8240, total_duration: 1663338.955484
# id: 481, total_duration: 1190243.460445
# id: 9294, total_duration: 532131.14278
# id: 3314, total_duration: 1791007.285418
# id: 9348, total_duration: 808611.2245540001
# id: 4457, total_duration: 944080.2083840002
# id: 7004, total_duration: 965877.0921709999
# id: 2446, total_duration: 2261734.6208470003
# id: 9111, total_duration: 1220838.373489
# id: 3378, total_duration: 212051.659609
# id: 1361, total_duration: 996463.2745660001
# id: 3884, total_duration: 1213191.686058
# id: 9954, total_duration: 1364420.625062
# id: 573, total_duration: 1657792.2116110001
# id: 4077, total_duration: 780055.942278
# id: 7721, total_duration: 1074089.92817
# id: 5289, total_duration: 344873.243874
# id: 812, total_duration: 643058.7530990002
# id: 1434, total_duration: 1443503.5919789998
# id: 5078, total_duration: 209329.195322
# id: 7603, total_duration: 1250221.410366
# id: 1875, total_duration: 221053.085421
# id: 3693, total_duration: 992892.3216679998
# id: 1896, total_duration: 958368.8040659999
# id: 3254, total_duration: 907641.376147
# id: 9190, total_duration: 1672396.4714859999
# id: 9170, total_duration: 890717.9806839998
# id: 3497, total_duration: 205538.73490000004
# id: 8000, total_duration: 442073.627465
# id: 3140, total_duration: 702874.1866459999
# id: 5127, total_duration: 1195513.562486
# id: 3866, total_duration: 491898.692949
# id: 7377, total_duration: 247695.804714
# id: 4023, total_duration: 299126.149161
# id: 6719, total_duration: 2158701.066285
# id: 756, total_duration: 217842.13728900003
# id: 1890, total_duration: 1319400.109673
# id: 6769, total_duration: 1256452.1783870002
# id: 2388, total_duration: 655393.9093899999
# id: 9729, total_duration: 242309.419007
# id: 2886, total_duration: 1216327.9674739998
# id: 3244, total_duration: 1148156.102562
# id: 7164, total_duration: 2260360.10401
# id: 2935, total_duration: 1670769.5998019997
# id: 6261, total_duration: 687740.6876699999
# id: 2313, total_duration: 1304404.9743350004
# id: 3911, total_duration: 2852609.121495
# id: 1959, total_duration: 1958831.8175080002
# id: 6174, total_duration: 1891192.537191
# id: 1993, total_duration: 225949.40000999998
# id: 2024, total_duration: 1721685.5062380002
# id: 7881, total_duration: 748846.816783
# id: 8540, total_duration: 2079915.86452
# id: 3309, total_duration: 1680657.5366379994
# id: 5758, total_duration: 1366900.5332499999
# id: 5981, total_duration: 217896.05093699996
# id: 2371, total_duration: 1125992.732477
# id: 5053, total_duration: 1236291.010122
# id: 492, total_duration: 1242034.897579
# id: 1974, total_duration: 849067.370583
# id: 3558, total_duration: 341141.618346
# id: 2985, total_duration: 152305.477844
# id: 9384, total_duration: 2376972.288489001
# id: 2397, total_duration: 1304070.997465
# id: 6946, total_duration: 605196.153989
# id: 5318, total_duration: 1155393.120329
# id: 2539, total_duration: 782686.1106649998
# id: 5912, total_duration: 1168053.6811570001
# id: 6896, total_duration: 441759.698153
# id: 8805, total_duration: 876871.2760279998
# id: 6403, total_duration: 379419.5394959999
# id: 2335, total_duration: 890251.966991
# id: 7027, total_duration: 1377297.7792579997
# id: 9594, total_duration: 2047572.322943
# id: 7215, total_duration: 1238805.2006770002
# id: 8536, total_duration: 1437274.7323950003
# id: 832, total_duration: 837496.685984
# id: 61, total_duration: 1137600.6085960001
# id: 5588, total_duration: 986907.857448
# id: 7130, total_duration: 312887.708303
# id: 4971, total_duration: 1112418.1681670002
# id: 3468, total_duration: 305560.93029499997
# id: 3996, total_duration: 1712063.9969970002
# id: 2997, total_duration: 1109553.5851789997
# id: 5645, total_duration: 253689.034137
# id: 7146, total_duration: 1838404.1834630002
# id: 8243, total_duration: 270263.62108
# id: 6244, total_duration: 205623.207147
# id: 5174, total_duration: 1015120.8757949999
# id: 1799, total_duration: 453201.82862
# id: 4171, total_duration: 297562.966524
# id: 866, total_duration: 806009.0823439999
# id: 4669, total_duration: 1558805.3457710003
# id: 331, total_duration: 2055062.8441849998
# id: 5427, total_duration: 852595.8233119999
# id: 7424, total_duration: 254592.58246799998
# id: 8054, total_duration: 1983668.5412690004
# id: 1211, total_duration: 1082350.5173560001
# id: 7767, total_duration: 1142533.2472009999
# id: 8192, total_duration: 652889.412726
# id: 2310, total_duration: 392308.471335
# id: 4451, total_duration: 1807957.495259
# id: 5278, total_duration: 535969.289006
# id: 3721, total_duration: 1070379.7279100001
# id: 6160, total_duration: 953944.99723
# id: 486, total_duration: 539696.944264
# id: 9846, total_duration: 764654.901636
# id: 5957, total_duration: 986298.569386
# id: 6050, total_duration: 759442.8789039999
# id: 1733, total_duration: 940168.4385379999
# id: 3632, total_duration: 682992.2950719999
# id: 3090, total_duration: 276892.263436
# id: 3302, total_duration: 281520.306718
# id: 9284, total_duration: 864816.297971
# id: 6473, total_duration: 984690.633811
# id: 7799, total_duration: 1391531.849855
# id: 7918, total_duration: 1866565.3500660004
# id: 388, total_duration: 166210.99723799998
# id: 6662, total_duration: 1971702.5507480002
# id: 7604, total_duration: 1159682.875676
# id: 9144, total_duration: 458792.12788000004
# id: 8952, total_duration: 1059880.162892
# id: 27, total_duration: 220495.934121
# id: 9638, total_duration: 1132714.6113309998
# id: 5686, total_duration: 1092858.3384180001
# id: 9171, total_duration: 2502394.905695001
# id: 3860, total_duration: 194125.414808
# id: 5180, total_duration: 1234213.2663539997
# id: 1963, total_duration: 517446.9743789999
# id: 256, total_duration: 365115.388262
# id: 1860, total_duration: 681150.5800260002
# id: 6202, total_duration: 781995.4869860001
# id: 6682, total_duration: 423045.263888
# id: 6906, total_duration: 801444.1483510002
# id: 7511, total_duration: 209539.145642
# id: 1656, total_duration: 312409.26616400003
# Converting question to SQL What is the total value of cases that have at least one recorded activity?
# Generated SQL query: SELECT SUM(c.value) AS total_value
# FROM cases c
# JOIN activity a ON c.id = a.case
# WHERE a.tpt > 0;
# Executing SQL query: SELECT SUM(c.value) AS total_value
# FROM cases c
# JOIN activity a ON c.id = a.case
# WHERE a.tpt > 0;
# SQL SELECT query executed successfully.
# total_value: 120326200

# %%
df_results
# Out:
#                                              Question  \
# 0   How many cases are there in total in the datab...
# 1             How many activities have been recorded?
# 2   What are the different types of insurance avai...
# 3   What is the total value of approved insurance ...
# 4             How many cases were created in January?
# 5     Who is the broker with the most assigned cases?
# 6   What is the most frequent activity in the data...
# 7   What is the total insurance value for each typ...
# 8   On average, how long does it take for an insur...
# 9   What is the average number of activities per c...
# 10  What is the most frequent activity performed i...
# 11  What is the total duration of all activities f...
# 12  What is the total value of cases that have at ...
#
#                                    Expected SQL Query  \
# 0                         SELECT COUNT(*) FROM cases;
# 1                      SELECT COUNT(*) FROM activity;
# 2                    SELECT DISTINCT type FROM cases;
# 3    SELECT SUM(value) FROM cases WHERE approved = 1;
# 4   SELECT COUNT(*) FROM cases WHERE EXTRACT(MONTH...
# 5   SELECT brocker FROM cases GROUP BY brocker ORD...
# 6   SELECT name FROM activity GROUP BY name ORDER ...
# 7   SELECT ramo, SUM(value) FROM cases GROUP BY ramo;
# 8   SELECT AVG(EXTRACT(DAY FROM insurance_start - ...
# 9   SELECT COUNT(activity.id) / COUNT(DISTINCT cas...
# 10  SELECT activity.name FROM activity INNER JOIN ...
# 11  SELECT activity.case, SUM(activity.tpt) FROM a...
# 12  SELECT SUM(cases.value) FROM cases WHERE cases...
#
#                                   Generated SQL Query  \
# 0                         SELECT COUNT(*) FROM cases;
# 1   SELECT COUNT(a."id") AS "number_of_activities"...
# 2   SELECT c.type \nFROM cases c \nJOIN activity a...
# 3   SELECT SUM(c.value) AS total_approved_insuranc...
# 4   SELECT COUNT(a."case") AS "count"\nFROM activi...
# 5   SELECT a."broker", COUNT(c."id") AS "num_cases...
# 6   SELECT a.name AS "Activity", COUNT(a.id) AS "C...
# 7   SELECT c."type", SUM(c."value") AS "total_insu...
# 8   SELECT AVG(a."tpt") AS "avg_time" FROM c JOIN ...
# 9   SELECT \n    c.id, \n    AVG(a.tpt) AS avg_act...
# 10  SELECT a.name AS "Activity", COUNT(a.id) AS "F...
# 11  SELECT c.id, SUM(a.tpt) AS total_duration\nFRO...
# 12  SELECT SUM(c.value) AS total_value\nFROM cases...
#
#                                          Query Result  Execution Time (s)
# 0                                  count_star(): 1000            1.132163
# 1   number_of_activities: 1\nnumber_of_activities:...            1.974502
# 2   type: Policy onboarding\ntype: Issuance\ntype:...            2.146427
# 3           total_approved_insurance_value: 112080900            2.214971
# 4                                            count: 0            2.544626
# 5   Error executing SQL query: Binder Error: Table...            2.547432
# 6   Activity: Enviar a Revisión suscripción, Count...            2.444983
# 7   type: Renewal, total_insurance_value: 36234600...            2.243066
# 8   Error executing SQL query: Query must target o...            1.879625
# 9   id: 9488, avg_activity_duration: 14373.7217918...            2.589537
# 10  Activity: Revisión en emisión, Frequency: 1112...            2.568293
# 11  id: 4915, total_duration: 1085399.309137\nid: ...            2.051247
# 12                             total_value: 120326200            1.986803

# %%
df_results.to_csv("results_vicuna.csv", index=False)
